# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
from crewai import Agent, Task, Crew, Process, LLM
from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource

# Create an LLM with a temperature of 0 to ensure deterministic outputs
llm = LLM(
    model="gemini/gemini-2.5-flash-preview-04-17",
    temperature=0.7,
)

# Create a knowledge source
content = "Users name is John. He is 30 years old and lives in San Francisco."
string_source = StringKnowledgeSource(content=content)

# %%
embedder_config = {
    "provider": "google",
    "config": {
        "model": "text-embedding-004",
        "api_key": os.environ["GEMINI_API_KEY"]
    }
}

# %%
# Create an agent with the knowledge store
agent = Agent(
    role="About User",
    goal="You know everything about the user.",
    backstory="You are a master at understanding people and their preferences.",
    verbose=True,
    allow_delegation=False,
    llm=llm,
)

task = Task(
    description="Answer the following questions about the user: {question}",
    expected_output="An answer to the question.",
    agent=agent,
)

crew = Crew(
    # memory=True,
    agents=[agent],
    tasks=[task],
    verbose=True,
    process=Process.sequential,
    # knowledge_sources=[string_source], # Enable knowledge by adding the sources here
    # embedder=embedder_config
)

# %%
result = crew.kickoff(inputs={"question": "What city does Donald Trump in and how old is he?"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d62ca688-4836-4e25-a2a5-13c275804cfd                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: About User
# ## Task: Answer the following questions about the user: What city does Donald Trump in and how old is he?
# Output()
# [1m[95m# Agent:[00m [1m[92mAbout User[00m
#  Error details: maximum recursion depth exceeded
# # Agent: About User
# ## Task: Answer the following questions about the user: What city does Donald Trump in and how old is he?
# [1m[95m# Agent:[00m [1m[92mAbout User[00m
# # Agent: About User
# ## Task: Answer the following questions about the user: What city does Donald Trump in and how old is he?
# [1m[95m# Agent:[00m [1m[92mAbout User[00m
#  Error details: maximum recursion depth exceeded
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── Task Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: 03af8a15-e30e-40dc-b956-c81b73d8da0b                                                                     │
# │  Agent: About User                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: d62ca688-4836-4e25-a2a5-13c275804cfd                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:396, in Agent.execute_task(self, task, context, tools)
#     395     else:
# --> 396         result = self._execute_without_timeout(task_prompt, task)
#     398 except TimeoutError as e:
#     399     # Propagate TimeoutError without retry
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:492, in Agent._execute_without_timeout(self, task_prompt, task)
#     483 """Execute a task without a timeout.
#     484
#     485 Args:
#    (...)    490     The output of the agent.
#     491 """
# --> 492 return self.agent_executor.invoke(
#     493     {
#     494         "input": task_prompt,
#     495         "tool_names": self.agent_executor.tools_names,
#     496         "tools": self.agent_executor.tools_description,
#     497         "ask_for_human_input": task.human_input,
#     498     }
#     499 )["output"]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:123, in CrewAgentExecutor.invoke(self, inputs)
#     122     else:
# --> 123         raise e
#     125 if self.ask_for_human_input:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:228, in CrewAgentExecutor._invoke_loop(self)
#     227 assert isinstance(formatted_answer, AgentFinish)
# --> 228 self._show_logs(formatted_answer)
#     229 return formatted_answer
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:280, in CrewAgentExecutor._show_logs(self, formatted_answer)
#     279     raise ValueError("Agent cannot be None")
# --> 280 show_agent_logs(
#     281     printer=self._printer,
#     282     agent_role=self.agent.role,
#     283     formatted_answer=formatted_answer,
#     284     verbose=self.agent.verbose
#     285     or (hasattr(self, "crew") and getattr(self.crew, "verbose", False)),
#     286 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:411, in show_agent_logs(printer, agent_role, formatted_answer, task_description, verbose)
#     409 else:
#     410     # Execution logs
# --> 411     printer.print(
#     412         content=f"\n\n\033\033# Agent:\033 \033\033{agent_role}\033"
#     413     )
#     415     if isinstance(formatted_answer, AgentAction):
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\utilities\printer.py:35, in Printer.print(self, content, color)
#      34 else:
# ---> 35     print(content)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      42 console = self.__console
# ---> 43 with console:
#      44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\decorator.py:234, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
# --> 234     args, kw = fix(args, kw, sig)
#     235 return caller(func, *(extras + args), **kw)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\decorator.py:204, in fix(args, kwargs, sig)
#     201 """
#     202 Fix args and kwargs to be consistent with the signature
#     203 """
# --> 204 ba = sig.bind(*args, **kwargs)
#     205 ba.apply_defaults()  # needed for test_dan_schult
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3204, in Signature.bind(self, *args, **kwargs)
#    3200 """Get a BoundArguments object, that maps the passed `args`
#    3201 and `kwargs` to the function's signature.  Raises `TypeError`
#    3202 if the passed arguments can not be bound.
#    3203 """
# -> 3204 return self._bind(args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3073, in Signature._bind(self, args, kwargs, partial)
#    3071 arguments = {}
# -> 3073 parameters = iter(self.parameters.values())
#    3074 parameters_ex = ()
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1705, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1704     for renderable in renderables:
# -> 1705         extend(render(renderable, render_options))
#    1706 else:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1326, in Console.render(self, renderable, options)
#    1325 _options = _options.reset_height()
# -> 1326 for render_output in iter_render:
#    1327     if isinstance(render_output, _Segment):
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:706, in Text.__rich_console__(self, console, options)
#     705 all_lines = Text("\n").join(lines)
# --> 706 yield from all_lines.render(console, end=self.end)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:775, in Text.render(self, console, end)
#     774     if next_offset > offset:
# --> 775         yield _Segment(text[offset:next_offset], get_current_style())
#     776 if end:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:765, in Text.render.<locals>.get_current_style()
#     764     return cached_style
# --> 765 current_style = combine(styles)
#     766 style_cache[styles] = current_style
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\style.py:611, in Style.combine(cls, styles)
#     610 iter_styles = iter(styles)
# --> 611 return sum(iter_styles, next(iter_styles))
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\style.py:758, in Style.__add__(self, style)
#     757 def __add__(self, style: Optional["Style"]) -> "Style":
# --> 758     combined_style = self._add(style)
#     759     return combined_style.copy() if combined_style.link else combined_style
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\style.py:425, in Style.__eq__(self, other)
#     424     return NotImplemented
# --> 425 return self.__hash__() == other.__hash__()
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:396, in Agent.execute_task(self, task, context, tools)
#     395     else:
# --> 396         result = self._execute_without_timeout(task_prompt, task)
#     398 except TimeoutError as e:
#     399     # Propagate TimeoutError without retry
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:492, in Agent._execute_without_timeout(self, task_prompt, task)
#     483 """Execute a task without a timeout.
#     484
#     485 Args:
#    (...)    490     The output of the agent.
#     491 """
# --> 492 return self.agent_executor.invoke(
#     493     {
#     494         "input": task_prompt,
#     495         "tool_names": self.agent_executor.tools_names,
#     496         "tools": self.agent_executor.tools_description,
#     497         "ask_for_human_input": task.human_input,
#     498     }
#     499 )["output"]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:123, in CrewAgentExecutor.invoke(self, inputs)
#     122     else:
# --> 123         raise e
#     125 if self.ask_for_human_input:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:228, in CrewAgentExecutor._invoke_loop(self)
#     227 assert isinstance(formatted_answer, AgentFinish)
# --> 228 self._show_logs(formatted_answer)
#     229 return formatted_answer
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:280, in CrewAgentExecutor._show_logs(self, formatted_answer)
#     279     raise ValueError("Agent cannot be None")
# --> 280 show_agent_logs(
#     281     printer=self._printer,
#     282     agent_role=self.agent.role,
#     283     formatted_answer=formatted_answer,
#     284     verbose=self.agent.verbose
#     285     or (hasattr(self, "crew") and getattr(self.crew, "verbose", False)),
#     286 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:411, in show_agent_logs(printer, agent_role, formatted_answer, task_description, verbose)
#     409 else:
#     410     # Execution logs
# --> 411     printer.print(
#     412         content=f"\n\n\033\033# Agent:\033 \033\033{agent_role}\033"
#     413     )
#     415     if isinstance(formatted_answer, AgentAction):
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\utilities\printer.py:35, in Printer.print(self, content, color)
#      34 else:
# ---> 35     print(content)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      42 console = self.__console
# ---> 43 with console:
#      44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 """Exit buffer context."""
# --> 864 self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2033 from .jupyter import display
# -> 2035 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036 del self._buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\decorator.py:234, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
# --> 234     args, kw = fix(args, kw, sig)
#     235 return caller(func, *(extras + args), **kw)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\decorator.py:204, in fix(args, kwargs, sig)
#     201 """
#     202 Fix args and kwargs to be consistent with the signature
#     203 """
# --> 204 ba = sig.bind(*args, **kwargs)
#     205 ba.apply_defaults()  # needed for test_dan_schult
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3204, in Signature.bind(self, *args, **kwargs)
#    3200 """Get a BoundArguments object, that maps the passed `args`
#    3201 and `kwargs` to the function's signature.  Raises `TypeError`
#    3202 if the passed arguments can not be bound.
#    3203 """
# -> 3204 return self._bind(args, kwargs)
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1705, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1704     for renderable in renderables:
# -> 1705         extend(render(renderable, render_options))
#    1706 else:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1326, in Console.render(self, renderable, options)
#    1325 _options = _options.reset_height()
# -> 1326 for render_output in iter_render:
#    1327     if isinstance(render_output, _Segment):
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:697, in Text.__rich_console__(self, console, options)
#     695 overflow = self.overflow or options.overflow or DEFAULT_OVERFLOW
# --> 697 lines = self.wrap(
#     698     console,
#     699     options.max_width,
#     700     justify=justify,
#     701     overflow=overflow,
#     702     tab_size=tab_size or 8,
#     703     no_wrap=pick_bool(self.no_wrap, options.no_wrap, False),
#     704 )
#     705 all_lines = Text("\n").join(lines)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:1231, in Text.wrap(self, console, width, justify, overflow, tab_size, no_wrap)
#    1230 lines = Lines()
# -> 1231 for line in self.split(allow_blank=True):
#    1232     if "\t" in line:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:1084, in Text.split(self, separator, include_separator, allow_blank)
#    1083 if separator not in text:
# -> 1084     return Lines([self.copy()])
#    1086 if include_separator:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:445, in Text.copy(self)
#     444 """Return a copy of this instance."""
# --> 445 copy_self = Text(
#     446     self.plain,
#     447     style=self.style,
#     448     justify=self.justify,
#     449     overflow=self.overflow,
#     450     no_wrap=self.no_wrap,
#     451     end=self.end,
#     452     tab_size=self.tab_size,
#     453 )
#     454 copy_self._spans[:] = self._spans
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\text.py:156, in Text.__init__(self, text, style, justify, overflow, no_wrap, end, tab_size, spans)
#     144 def __init__(
#     145     self,
#     146     text: str = "",
#    (...)    154     spans: Optional[List[Span]] = None,
#     155 ) -> None:
# --> 156     sanitized_text = strip_control_codes(text)
#     157     self._text = [sanitized_text]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\control.py:198, in strip_control_codes(text, _translate_table)
#     190 """Remove control codes from text.
#     191
#     192 Args:
#    (...)    196     str: String with control codes removed.
#     197 """
# --> 198 return text.translate(_translate_table)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 result = crew.kickoff(inputs={"question": "What city does Donald Trump in and how old is he?"})
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\crew.py:661, in Crew.kickoff(self, inputs)
#     658 metrics: List[UsageMetrics] = []
#     660 if self.process == Process.sequential:
# --> 661     result = self._run_sequential_process()
#     662 elif self.process == Process.hierarchical:
#     663     result = self._run_hierarchical_process()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\crew.py:773, in Crew._run_sequential_process(self)
#     771 def _run_sequential_process(self) -> CrewOutput:
#     772     """Executes tasks sequentially and returns the final output."""
# --> 773     return self._execute_tasks(self.tasks)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\crew.py:876, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     873     futures.clear()
#     875 context = self._get_context(task, task_outputs)
# --> 876 task_output = task.execute_sync(
#     877     agent=agent_to_use,
#     878     context=context,
#     879     tools=cast(List[BaseTool], tools_for_task),
#     880 )
#     881 task_outputs.append(task_output)
#     882 self._process_task_result(task, task_output)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\task.py:351, in Task.execute_sync(self, agent, context, tools)
#     344 def execute_sync(
#     345     self,
#     346     agent: Optional[BaseAgent] = None,
#     347     context: Optional[str] = None,
#     348     tools: Optional[List[BaseTool]] = None,
#     349 ) -> TaskOutput:
#     350     """Execute the task synchronously."""
# --> 351     return self._execute_core(agent, context, tools)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\task.py:495, in Task._execute_core(self, agent, context, tools)
#     493 self.end_time = datetime.datetime.now()
#     494 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 495 raise e
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\task.py:415, in Task._execute_core(self, agent, context, tools)
#     413 self.processed_by_agents.add(agent.role)
#     414 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 415 result = agent.execute_task(
#     416     task=self,
#     417     context=context,
#     418     tools=tools,
#     419 )
#     421 pydantic_output, json_output = self._export_output(result)
#     422 task_output = TaskOutput(
#     423     name=self.name,
#     424     description=self.description,
#    (...)    430     output_format=self._get_output_format(),
#     431 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:432, in Agent.execute_task(self, task, context, tools)
#     423         crewai_event_bus.emit(
#     424             self,
#     425             event=AgentExecutionErrorEvent(
#    (...)    429             ),
#     430         )
#     431         raise e
# --> 432     result = self.execute_task(task, context, tools)
#     434 if self.max_rpm and self._rpm_controller:
#     435     self._rpm_controller.stop_rpm_counter()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:432, in Agent.execute_task(self, task, context, tools)
#     423         crewai_event_bus.emit(
#     424             self,
#     425             event=AgentExecutionErrorEvent(
#    (...)    429             ),
#     430         )
#     431         raise e
# --> 432     result = self.execute_task(task, context, tools)
#     434 if self.max_rpm and self._rpm_controller:
#     435     self._rpm_controller.stop_rpm_counter()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:431, in Agent.execute_task(self, task, context, tools)
#     422     if self._times_executed > self.max_retry_limit:
#     423         crewai_event_bus.emit(
#     424             self,
#     425             event=AgentExecutionErrorEvent(
#    (...)    429             ),
#     430         )
# --> 431         raise e
#     432     result = self.execute_task(task, context, tools)
#     434 if self.max_rpm and self._rpm_controller:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:396, in Agent.execute_task(self, task, context, tools)
#     392         result = self._execute_with_timeout(
#     393             task_prompt, task, self.max_execution_time
#     394         )
#     395     else:
# --> 396         result = self._execute_without_timeout(task_prompt, task)
#     398 except TimeoutError as e:
#     399     # Propagate TimeoutError without retry
#     400     crewai_event_bus.emit(
#     401         self,
#     402         event=AgentExecutionErrorEvent(
#    (...)    406         ),
#     407     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agent.py:492, in Agent._execute_without_timeout(self, task_prompt, task)
#     482 def _execute_without_timeout(self, task_prompt: str, task: Task) -> str:
#     483     """Execute a task without a timeout.
#     484
#     485     Args:
#    (...)    490         The output of the agent.
#     491     """
# --> 492     return self.agent_executor.invoke(
#     493         {
#     494             "input": task_prompt,
#     495             "tool_names": self.agent_executor.tools_names,
#     496             "tools": self.agent_executor.tools_description,
#     497             "ask_for_human_input": task.human_input,
#     498         }
#     499     )["output"]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:123, in CrewAgentExecutor.invoke(self, inputs)
#     121         raise e
#     122     else:
# --> 123         raise e
#     125 if self.ask_for_human_input:
#     126     formatted_answer = self._handle_human_feedback(formatted_answer)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     107 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#     112     self._printer.print(
#     113         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     114         color="red",
#     115     )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:228, in CrewAgentExecutor._invoke_loop(self)
#     223 # During the invoke loop, formatted_answer alternates between AgentAction
#     224 # (when the agent is using tools) and eventually becomes AgentFinish
#     225 # (when the agent reaches a final answer). This assertion confirms we've
#     226 # reached a final answer and helps type checking understand this transition.
#     227 assert isinstance(formatted_answer, AgentFinish)
# --> 228 self._show_logs(formatted_answer)
#     229 return formatted_answer
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:280, in CrewAgentExecutor._show_logs(self, formatted_answer)
#     278 if self.agent is None:
#     279     raise ValueError("Agent cannot be None")
# --> 280 show_agent_logs(
#     281     printer=self._printer,
#     282     agent_role=self.agent.role,
#     283     formatted_answer=formatted_answer,
#     284     verbose=self.agent.verbose
#     285     or (hasattr(self, "crew") and getattr(self.crew, "verbose", False)),
#     286 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:411, in show_agent_logs(printer, agent_role, formatted_answer, task_description, verbose)
#     406         printer.print(
#     407             content=f"\033## Task:\033 \033{task_description}\033"
#     408         )
#     409 else:
#     410     # Execution logs
# --> 411     printer.print(
#     412         content=f"\n\n\033\033# Agent:\033 \033\033{agent_role}\033"
#     413     )
#     415     if isinstance(formatted_answer, AgentAction):
#     416         thought = re.sub(r"\n+", "\n", formatted_answer.thought)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\crewai\utilities\printer.py:35, in Printer.print(self, content, color)
#      33     self._print_green(content)
#      34 else:
# ---> 35     print(content)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      41 if lines:
#      42     console = self.__console
# ---> 43     with console:
#      44         output = Text("\n").join(
#      45             self.__ansi_decoder.decode_line(line) for line in lines
#      46         )
#      47         console.print(output)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     201 format_dict = {}
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#     208 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\decorator.py:234, in decorate.<locals>.fun(*args, **kw)
#     232 def fun(*args, **kw):
#     233     if not kwsyntax:
# --> 234         args, kw = fix(args, kw, sig)
#     235     return caller(func, *(extras + args), **kw)
#
# File c:\Users\KannanGnanasekaran\GIT\crewai-basics\.venv\Lib\site-packages\decorator.py:204, in fix(args, kwargs, sig)
#     200 def fix(args, kwargs, sig):
#     201     """
#     202     Fix args and kwargs to be consistent with the signature
#     203     """
# --> 204     ba = sig.bind(*args, **kwargs)
#     205     ba.apply_defaults()  # needed for test_dan_schult
#     206     return ba.args, ba.kwargs
#
# RecursionError: maximum recursion depth exceeded
